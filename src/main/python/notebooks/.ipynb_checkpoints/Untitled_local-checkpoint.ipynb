# %%
import pandas as pd
import sys
from pyspark.sql import SparkSession

sys.path.insert(0,"../utils.zip")
from utils.spark_utils import spark_session

spark = spark_session()
#spark = SparkSession.builder.getOrCreate()

# %load_ext autoreload
# %autoreload 2

from utils.gf_utils import *
from utils.df_utils import *
from utils.draw_utils import *
from utils.spark_utils import *
from utils.read_write_utils import *
from pyspark.sql import functions as F
# %config InlineBackend.figure_format = 'retina'

# %%
spark.sparkContext.addPyFile("../utils.zip")

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://172.20.10.2:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v2.4.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
gf_domip = gf_read( spark, "/Users/olaya/Documents/Master/TFM/output_fraud/graph_domain_ip_all_180208" )
# Out:
#  Leemos el grafo  en el path :/Users/olaya/Documents/Master/TFM/output_fraud/graph_domain_ip_all_180208

# %%
df_domip_filtered_edges = gf_domip.edges.filter( gf_domip.edges.edge_weight > 200 )

# %%
df_domip_filtered_edges.count()
# Out:
# 15

# %%
draw_nx( df_domip_filtered_edges )
# Out:
# df_utils draw_nx --
# df_utils draw_nx -- -- despues nx.Graph()
# df_utils draw_nx -- -- despues add_nodes_from src
# df_utils draw_nx -- -- despues add_nodes_from dst
# df_utils draw_nx -- -- Nodes added to B
# df_utils draw_nx -- -- despues de pos.update
# df_utils draw_nx -- -- despues for
# df_utils draw_nx -- -- ante de plot

# %%
ig = Graph.TupleList( gf_domip.edges.filter( gf_domip.edges.edge_weight > 200 ).collect(), directed=True )

# %%
visual_style = {}
N_vertices = ig.vcount()

layout = ig.layout( "kk" )
colors = ["lightgray", "cyan", "magenta", "yellow", "blue", "green", "red"]
for component in ig.components():
    color = colors[min( 6, len( component ) - 1 )]
    for vidx in component: ig.vs[vidx]["color"] = color

visual_style["vertex_size"] = 20
visual_style["vertex_label"] = ig.vs["name"]
visual_style["vertex_label_size"] = 14
visual_style["vertex_label_dist"] = 1
visual_style["vertex_label_angle"] = -1
visual_style["layout"] = layout
visual_style["bbox"] = (25 * N_vertices, 25 * N_vertices)  # (600,600)
visual_style["margin"] = 50
visual_style["main"] = "-- igraph plot :"

# %%
plot( ig, **visual_style )

# %%
df_degree_ratio=get_df_degree_ratio(gf_domip)
# Out:
# gf_utils get_motifs -- df_motifs
# +--------------------+--------------------+---------------+--------------------+--------------------+
# |                   a|                   e|              b|                   c|                  e2|
# +--------------------+--------------------+---------------+--------------------+--------------------+
# |         [429610587]|[429610587, 107.7...|[107.77.161.11]|        [jb.zcamera]|[jb.zcamera, 107....|
# |         [473299958]|[473299958, 142.1...| [142.169.78.0]|      [thegamer.com]|[thegamer.com, 14...|
# |[abs.workout.fitn...|[abs.workout.fitn...|[107.77.249.11]|[best.deals.compa...|[best.deals.compa...|
# |[apalon.myclockfree]|[apalon.myclockfr...|[107.77.161.12]|  [jiubang.go.music]|[jiubang.go.music...|
# |[apalon.myclockfree]|[apalon.myclockfr...| [107.77.173.4]|[kitkatandroid.ke...|[kitkatandroid.ke...|
# |[apalon.myclockfree]|[apalon.myclockfr...| [107.77.173.7]|[best.deals.compa...|[best.deals.compa...|
# ...

# %%
df_write(df_degree_ratio, "/Users/olaya/Documents/Master/TFM/output_fraud/df_degree_ratio_all_180208")
# Out:
#  Salvado df en el path :/Users/olaya/Documents/Master/TFM/output_fraud/df_degree_ratio_all_180208

# %%
gf_domdom = get_graph_domdom( gf_domip ).persist()
# Out:
# DomainDomainGraph get_graph_domdom -- g_domip.edges.show()
# +--------------------+---------------+-----------+
# |                 src|            dst|edge_weight|
# +--------------------+---------------+-----------+
# |       adaudience.de|   185.17.207.0|         16|
# |       adaudience.de|   80.187.104.0|         18|
# |animatures.cartoo...|  31.35.240.122|         17|
# |        babygaga.com|   172.58.109.0|         46|
# |     centurylink.net| 184.100.81.213|         20|
# |  coolmath-games.com|  12.189.45.194|         22|
# |     dailymail.co.uk|  194.176.105.0|         66|
# |           diply.com|    172.56.28.0|         19|
# |   dupovalo.goroskop|  188.195.21.98|         16|
# |       dupovalo.name|    70.68.25.38|         17|
# |emoji.keyboard.em...|    65.30.8.124|         16|
# |     flightaware.com| 66.165.168.150|         21|
# |formationapps.nam...|  73.212.39.227|         19|
# |formationapps.nam...|   84.136.96.34|         16|
# ...

# %%
gf_write( gf_domdom, "/Users/olaya/Documents/Master/TFM/output_fraud/graph_domain_domain_all_180208" )
# Out:
#  Salvado grafo en el path :/Users/olaya/Documents/Master/TFM/output_fraud/graph_domain_domain_all_180208

# %%
ig, visual_style = draw_igraph_domain_domain( gf_domdom )
# Out:
# gf_utils draw_igraph --

# %%
#plot( ig, **visual_style )

# %%
plot( ig,**visual_style ).save("/Users/olaya/Documents/Master/TFM/output_fraud/gf_domdom_prueba.png")  #"thesportster.com",

# %%
df_degree_ratio.sort(F.desc("edge_ratio")).filter((df_degree_ratio.outDegree>40) & (df_degree_ratio.outDegree!=df_degree_ratio.count_ips_in_common)).show(200,False)
# Out:
# +--------------------------------------------------------------+--------------------------------------------------------------+-------------------+------------------------------------------------------------+---------+------------------+
# |a                                                             |c                                                             |count_ips_in_common|id                                                          |outDegree|edge_ratio        |
# +--------------------------------------------------------------+--------------------------------------------------------------+-------------------+------------------------------------------------------------+---------+------------------+
# |[thethings.com]                                               |[thesportster.com]                                            |82                 |thethings.com                                               |83       |0.9879518072289156|
# ...

# %%
df_degree_ratio.sort(F.asc("edge_ratio")).show(200)
# Out:
# +--------------------+--------------------+-------------------+--------------------+---------+--------------------+
# |                   a|                   c|count_ips_in_common|                  id|outDegree|          edge_ratio|
# +--------------------+--------------------+-------------------+--------------------+---------+--------------------+
# |[coolmath-games.com]|       [mobi.ifunny]|                  1|  coolmath-games.com|      341|0.002932551319648094|
# |[coolmath-games.com]|        [slader.com]|                  1|  coolmath-games.com|      341|0.002932551319648094|
# |[coolmath-games.com]|[workingmothertv....|                  1|  coolmath-games.com|      341|0.002932551319648094|
# |[coolmath-games.com]|[twentytwowords.com]|                  1|  coolmath-games.com|      341|0.002932551319648094|
# |[coolmath-games.com]|        [woodtv.com]|                  1|  coolmath-games.com|      341|0.002932551319648094|
# ...

# %%
gf_domip_filtered_bad_domain=gf_domip.filterEdges("src='thesportster.com'")

# %%
draw_nx( gf_domip_filtered_bad_domain.edges )
# Out:
# df_utils draw_nx --
# df_utils draw_nx -- -- despues nx.Graph()
# df_utils draw_nx -- -- despues add_nodes_from src
# df_utils draw_nx -- -- despues add_nodes_from dst
# df_utils draw_nx -- -- Nodes added to B
# df_utils draw_nx -- -- despues de pos.update
# df_utils draw_nx -- -- despues for
# df_utils draw_nx -- -- ante de plot

# %%
ig, visual_style =draw_igraph_domain_domain(gf_domip_filtered_bad_domain)
# Out:
# gf_utils draw_igraph --

# %%
plot( ig, **visual_style )

# %%
plot( ig, **visual_style ).save("/Users/olaya/Documents/Master/TFM/output_fraud/prueba2.png")

# %%
gf_domip_filtered_bad_domain.edges.collect()
# Out:
# [Row(src='thesportster.com', dst='66.87.73.0', edge_weight=46),
#  Row(src='thesportster.com', dst='99.203.128.0', edge_weight=47),
#  Row(src='thesportster.com', dst='107.77.195.0', edge_weight=38),
#  Row(src='thesportster.com', dst='172.56.35.0', edge_weight=29),
#  Row(src='thesportster.com', dst='99.203.11.0', edge_weight=27),
#  Row(src='thesportster.com', dst='172.56.13.0', edge_weight=29),
#  Row(src='thesportster.com', dst='172.58.145.0', edge_weight=52),
#  Row(src='thesportster.com', dst='107.77.206.0', edge_weight=67),
#  Row(src='thesportster.com', dst='172.58.59.0', edge_weight=20),
#  Row(src='thesportster.com', dst='166.181.87.0', edge_weight=23),
#  Row(src='thesportster.com', dst='172.58.24.0', edge_weight=17),
#  Row(src='thesportster.com', dst='107.77.197.0', edge_weight=86),
#  Row(src='thesportster.com', dst='142.177.130.0', edge_weight=26),
#  Row(src='thesportster.com', dst='99.203.17.0', edge_weight=95),
# ...

# %%
ig = Graph.TupleList( gf_domip_filtered_bad_domain.edges.collect(), directed=True )

# %%
visual_style = {}
N_vertices = ig.vcount()

layout = ig.layout( "kk" )
colors = ["lightgray", "cyan", "magenta", "yellow", "blue", "green", "red"]
for component in ig.components():
    color = colors[min( 6, len( component ) - 1 )]
    for vidx in component: ig.vs[vidx]["color"] = color

visual_style["vertex_size"] = 20
visual_style["vertex_label"] = ig.vs["name"]
visual_style["vertex_label_size"] = 14
visual_style["vertex_label_dist"] = 1
visual_style["vertex_label_angle"] = -1
visual_style["layout"] = layout
visual_style["bbox"] = (25 * N_vertices, 25 * N_vertices)  # (600,600)
visual_style["margin"] = 50
visual_style["main"] = "-- igraph plot :"
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-89-ed6c5d9c9c4c> in <module>
#       9
#      10 visual_style["vertex_size"] = 20
# ---> 11 visual_style["vertex_label"] = ig.vs["name"]
#      12 visual_style["vertex_label_size"] = 14
#      13 visual_style["vertex_label_dist"] = 1
#
# KeyError: 'Attribute does not exist'

# %%
plot( ig,**visual_style )  #"thesportster.com",

# %%
gf_domip
# Out:
# GraphFrame(v:[id: string], e:[src: string, dst: string ... 1 more field])

# %%
sorted_degrees = sorted_degrees.limit(4)
sorted_degrees.printSchema()

print( "plots_main MAIN-- prueba" )
degree, id = zip(
    *[(item.degree, item.id) for item in sorted_degrees.select( "degree", "id" ).collect()] )

####--> Grafica : y= (edge_ratio = covisitation degree) x=dominios ó x=IPS (sacar las dos)

fig, ax = plt.subplots()

ax.bar(id,degree)
#ax.bar( id, degree )

ax.set_xticks( id  )
#ax.xlabel( "domain", fontsize=7)
#ax.ylabel( "degree", fontsize=7 )
#ax.title( "most visited domains", fontsize=7 )
plt.show()
# Out:
# root
#  |-- id: string (nullable = true)
#  |-- degree: integer (nullable = false)
#
# plots_main MAIN-- prueba

# %%
gf_domip

total_degrees = gf_domip.degrees
print( f" type  {type( total_degrees )}  " )
sorted_degrees = total_degrees.orderBy( F.desc( "degree" ) )
print( "gf_utils doms_more_visited -- sorted_degrees.show .. " )
sorted_degrees.show()
# Out:
#  type  <class 'pyspark.sql.dataframe.DataFrame'>
# gf_utils doms_more_visited -- sorted_degrees.show ..
# +--------------------+------+
# |                  id|degree|
# +--------------------+------+
# |  coolmath-games.com|   341|
# |           yahoo.com|   335|
# |formationapps.nam...|   334|
# |formationapps.wom...|   265|
# |  twentytwowords.com|   265|
# |         yieldlab.de|   231|
# |    yoolotto.android|   218|
# |rewardable.reward...|   205|
# |     mobileposse.com|   193|
# |   talkatone.android|   186|
# |    thesportster.com|   180|
# |emoji.keyboard.em...|   176|
# |kitkatandroid.key...|   172|
# |        babygaga.com|   153|
# |       adaudience.de|   140|
# |         momento.cam|   128|
# |      qihoo.security|   126|
# |dianxinos.optimiz...|   119|
# |          sh.whisper|   118|
# |jiubang.fastestfl...|   117|
# +--------------------+------+
# only showing top 20 rows

# %%
print( "plots_main MAIN-- prueba" )
degree, id = zip(
    *[(item.degree, item.id) for item in sorted_degrees.select( "degree", "id" ).collect()] )
# Out:
# plots_main MAIN-- prueba

# %%
plt.hist(degree,3)
# Out:
# (array([5919.,   14.,    6.]),
#  array([  1.        , 114.33333333, 227.66666667, 341.        ]),
#  <a list of 3 Patch objects>)

# %%
degree = np.array(degree)

print(degree.shape)
idx= np.where(degree>2)

degree_filt = degree[idx]
degree_filt.shape
# Out:
# (5939,)
# (536,)

# %% [markdown]
# # Draw_log_hist :
#
# ### Es escala logaritmica

# %%
import numpy as np

def draw_log_hist(degree,bins = 10 ):
    '''
    degree : node degree 
    bins: division del histograma, dos formas 
    
    draw_log_hist(degree,10):
    devuelve 10 barras con una division realizada por el np.histogram 
    
    draw_log_hist(degree,[1,10,100,200]):
    
    devuelve plot entre los numeros que le pases,
    es decir suma el numero de elementos que hay entre 1-10 , 10-100,100-200 ....
    
    ESCALA LOGARITMICA 
    
    '''
    degree = np.array(degree)
    hist_y,hist_x =  np.histogram(degree,bins)
    label_x= [ str(int(hist_x[i]))+"-"+str(int(hist_x[i+1])) for i in  range(hist_x.shape[0]-1)  ]
    plt.bar(label_x,np.log(hist_y+1))

# %%
draw_log_hist(degree,[1,10,100,200])

# %%
plt.hist(degree_filt,10)
# Out:
# (array([484.,  20.,   9.,   8.,   2.,   6.,   2.,   2.,   0.,   3.]),
#  array([  3. ,  36.8,  70.6, 104.4, 138.2, 172. , 205.8, 239.6, 273.4,
#         307.2, 341. ]),
#  <a list of 10 Patch objects>)

# %%
hist_y,hist_x =  np.histogram(degree,10)

# %%
    
label_x= [ str(int(hist_x[i]))+"-"+str(int(hist_x[i+1])) for i in  range(hist_x.shape[0]-1)  ]

# %%
plt.figure()
plt.bar(label_x,np.log(hist_y+1))
# Out:
# <BarContainer object of 10 artists>

# %%
np.log(hist_y+1).shape,hist_x.shape
# Out:
# ((10,), (11,))

# %% [markdown]
# # Elementos menores que unos valores:
#
# Graficamos los elementos que sean menores que unos valores, le pasamos el array de valores menores de los que queremos hacer

# %%
def draw_minor_than_list(degree,list_tope ):
    '''
    
    degree : degree a pintar
    list_tope: array de enteros con los topes
    funcion que representa los elementos que hay menores que un tope,
    cuantos hay menores que 400, menores que 300 , menores que 200 ....
    
    '''
    degree = np.array(degree)
    count_elemnt = [ np.sum(degree<=tope)   for tope in list_tope ]
    label_y=[ str(t) for t in list_tope]
    plt.bar(label_y,count_elemnt)

# %%
list_tope =  [400,300,200,100,50,10]
draw_minor_than_list(degree,list_tope)

# %%
np.where(degree<=tope)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-187-0b3d5c38a8c3> in <module>
# ----> 1 np.where(degree<=tope)
#
# NameError: name 'tope' is not defined

# %%
import numpy as np



plt.plot(np.log(np.arange(100)+1))
plt.show()

# %%
gf_domdom
# Out:
# GraphFrame(v:[id: struct<id: string>], e:[src: struct<id: string>, dst: struct<id: string> ... 1 more field])

# %% [markdown]
# # Confusion matrix :
#
# Vamos a calcular la relacion entre los dominios sospechosos para ver si estan relacionados entre si y luego haremos lo mismo para dominios random ,

# %%
suspicious_top_20=  df_degree_ratio.filter(
    "edge_ratio>0.5").sort(F.desc("edge_ratio")).select(df_degree_ratio.a.id,df_degree_ratio.c.id,df_degree_ratio.edge_ratio).take(20)

# %%
suspicious_top_20
# Out:
# [Row(a.id='flashlight.brightest.beacon.torch', c.id='steam.photoeditor', edge_ratio=1.0),
#  Row(a.id='philly.com', c.id='thetalko.com', edge_ratio=1.0),
#  Row(a.id='mk.ru', c.id='imasdk.googleapis.com', edge_ratio=1.0),
#  Row(a.id='ksmobile.launcher', c.id='cleanmaster.mguard', edge_ratio=1.0),
#  Row(a.id='jb.gokeyboardpro', c.id='myyearbook.m', edge_ratio=1.0),
#  Row(a.id='tnt-online.ru', c.id='mk.ru', edge_ratio=1.0),
#  Row(a.id='tunein.player', c.id='steam.photoeditor', edge_ratio=1.0),
#  Row(a.id='thequiz.com', c.id='babygaga.com', edge_ratio=1.0),
#  Row(a.id='284035177', c.id='pof.com', edge_ratio=1.0),
#  Row(a.id='pelmorex.weathereyeandroid', c.id='473299958', edge_ratio=1.0),
#  Row(a.id='tunein.player', c.id='taggedapp', edge_ratio=1.0),
#  Row(a.id='ticketmaster.com', c.id='offers.com', edge_ratio=1.0),
#  Row(a.id='mobdro.android', c.id='nitroxenon.terrarium', edge_ratio=1.0),
#  Row(a.id='ksmobile.launcher', c.id='pandora.android', edge_ratio=1.0),
# ...

# %%
df_degree_ratio.filter(
    "edge_ratio>0.5 and count_ips_in_common>1  ").sort(F.desc("outDegree"))..show(20)
# Out:
# +--------------------+--------------------+-------------------+--------------------+---------+------------------+
# |                   a|                   c|count_ips_in_common|                  id|outDegree|        edge_ratio|
# +--------------------+--------------------+-------------------+--------------------+---------+------------------+
# |       [yieldlab.de]|     [adaudience.de]|                132|         yieldlab.de|      231|0.5714285714285714|
# |  [thesportster.com]|      [babygaga.com]|                140|    thesportster.com|      180|0.7777777777777778|
# |  [thesportster.com]|      [thetalko.com]|                103|    thesportster.com|      180|0.5722222222222222|
# |      [babygaga.com]|         [diply.com]|                 81|        babygaga.com|      153|0.5294117647058824|
# |      [babygaga.com]|  [thesportster.com]|                140|        babygaga.com|      153|0.9150326797385621|
# ...

# %%
suspicius_top_20 =  df_degree_ratio.filter(
    "edge_ratio>0.5 and count_ips_in_common>1  ").select(
    df_degree_ratio.a.id,df_degree_ratio.outDegree).distinct().sort(F.desc("outDegree")).take(20)

# %%
l_suspicius_top_20 = [ row["a.id"]  for row in  suspicius_top_20]

# %%
matrix_src_dsc = df_degree_ratio.filter(
    (F.col("a.id").isin(l_suspicius_top_20)) & (F.col("c.id").isin(l_suspicius_top_20))).select(
    F.col("a.id").alias("src"),F.col("c.id").alias("dst"),F.col("edge_ratio")).collect()

# %%
matrix_src_dsc= [ (row['src'],row['dst'],row['edge_ratio']) for row in  matrix_src_dsc]

# %%
dom_idx = dict([ (v,k) for k,v in enumerate(l_suspicius_top_20)])

# %%
dom_matrix=  np.eye(len(l_suspicius_top_20))

# %%
plt.matshow(dom_matrix)

# %%
for s,d,e in matrix_src_dsc:
    dom_matrix[dom_idx[s],dom_idx[d]]=e

# %%
#plt.matshow(dom_matrix)
import matplotlib.ticker as ticker

fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(dom_matrix)
fig.colorbar(cax)

# Set up axes
ax.set_xticklabels(['']+l_suspicius_top_20, rotation=90)
ax.set_yticklabels(['']+l_suspicius_top_20)

ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

# %%
l_suspicius_top_20
# Out:
# ['yieldlab.de',
#  'thesportster.com',
#  'babygaga.com',
#  'adaudience.de',
#  'jiubang.fastestflashlight',
#  'jb.zcamera',
#  'thetalko.com',
#  'weather.weather',
#  'mobi.ifunny',
#  'diply.com',
#  'steam.photoeditor',
#  'myyearbook.m',
#  'thethings.com',
#  'jiubang.go.music',
#  'apalon.myclockfree',
#  'jb.emoji.gokeyboard',
#  'thegamer.com',
#  'emoji.keyboard.touchpal',
#  'latininput.keyboard',
#  'flashlight.brightestflashlightpro']

# %%
#### TE creees la fnuncion que te lo haga

# %%
top50_suspicious =  df_degree_ratio.filter(
    "edge_ratio>0.5 and count_ips_in_common>1  ").select(
    df_degree_ratio.a.id,df_degree_ratio.outDegree).distinct().sort(F.desc("outDegree")).take(50)

# %%
def draw_overlap_matrix(df_degree_ratio,list_top_suspicious,figsize=(10,10)):
    '''
    df_degree_ratio
    top_suspicious : number of top suspicious domains to plot
    
    '''
    import matplotlib.ticker as ticker
    
    
    
    matrix_src_dsc = df_degree_ratio.filter(
        (F.col("a.id").isin(list_top_suspicious)) & (F.col("c.id").isin(list_top_suspicious))).select(
        F.col("a.id").alias("src"),F.col("c.id").alias("dst"),F.col("edge_ratio")).collect()
    
    dom_idx = dict([ (v,k) for k,v in enumerate(list_top_suspicious)]) # diccionario con indice-dominio y lo invierto
    # para que me lo de dominio-indice de la matriz
    
    dom_matrix=  np.eye(len(list_top_suspicious))  # matriz con diagonal en 1's de la long de la lista de top_susp
    
    for s,d,e in matrix_src_dsc:  # relleno la matriz con los valores 
        dom_matrix[dom_idx[s],dom_idx[d]]=e
    
    fig = plt.figure(figsize=figsize) # tamaño de la matriz
    
    #fig.suptitle("Overlap domain matriz")
    ax = fig.add_subplot(111)
    cax = ax.matshow(dom_matrix)
    fig.colorbar(cax)
    
    # Set up axes
    # el primero vacio porque si no no pinta el q esta en la posicion 0
    ax.set_xticklabels(['']+list_top_suspicious, rotation=90) 
    ax.set_yticklabels(['']+list_top_suspicious)
    
    ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
    ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

# %%
a=  np.arange(3)

b = list(zip((a,a+1)))

# %%
ones_aux= np.ones((3,4))

# %%
ones_aux[b]=[2,3,4]
# Out:
# /Users/olaya/anaconda3/envs/fraud_36/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   """Entry point for launching an IPython kernel.

# %%
ones_aux
# Out:
# array([[1., 2., 1., 1.],
#        [1., 1., 3., 1.],
#        [1., 1., 1., 4.]])

# %%
list_top_suspicious = [ row["a.id"]  for row in  top50_suspicious]

draw_overlap_matrix(df_degree_ratio,list_top_suspicious)

# %%
sample_50_percent =  df_degree_ratio.select(F.col("a.id")).distinct().sample(0.2).take(20)

# cojo un 20% de datos totales (dominios unicos) de la muestra de manera aleatoria

# %%
list_sample = [ row["id"]  for row in  sample_50_percent]

draw_overlap_matrix(df_degree_ratio,list_sample)

# %%
# %config InlineBackend.figure_format = 'retina'

# %%
sample_50_percent =  df_degree_ratio.select(F.col("a.id")).distinct().sample(0.2).take(50)


list_sample = [ row["id"]  for row in  sample_50_percent]

draw_overlap_matrix(df_degree_ratio,list_sample)

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-310-252ff01d9a48> in <module>
#       1 list_sample = [ row["id"]  for row in  sample_50_percent]
#       2
# ----> 3 draw_overlap_matrix_new(df_degree_ratio,list_sample)
#
# <ipython-input-309-7b5c0f760775> in draw_overlap_matrix_new(df_degree_ratio, list_top_suspicious, figsize)
#      19     matrix_src_dsc,values=zip(*[ ((s,d),e) for s,d,e in matrix_src_dsc ])
#      20
# ---> 21     dom_matrix[matrix_src_dsc]=values
#      22
#      23     #for s,d,e in matrix_src_dsc:
#
# IndexError: too many indices for array
